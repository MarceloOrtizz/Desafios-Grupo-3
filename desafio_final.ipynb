# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Desafío 1: 📚  Carga de Datos
#
# Carga los tres CSV de Pokémon en diferentes DataFrames. Inspecciona los primeros registros, comprueba las dimensiones de los DataFrames y los tipos de datos de las columnas.

# %%
df_attri = pd.read_csv("pokemon_attributes.csv")
df_stats = pd.read_csv("pokemon_stats.csv")
df_type = pd.read_csv("pokemon_type.csv")

# %%
print(df_attri.shape, "\n")
print(df_attri.dtypes, "\n")
print(df_attri.info(), "\n")
df_attri.info()
# Out:
# (1015, 9)
#
# Unnamed: 0              int64
# name                   object
# ndex                  float64
# pokemon_species        object
# pokemon_weight_kg     float64
# pokemon_height_m      float64
# pokemon_male          float64
# pokemon_female         object
# pokemon_weight_grs    float64
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1015 non-null   int64
#  1   name                1015 non-null   object
#  2   ndex                1010 non-null   float64
#  3   pokemon_species     1015 non-null   object
#  4   pokemon_weight_kg   909 non-null    float64
#  5   pokemon_height_m    1003 non-null   float64
#  6   pokemon_male        862 non-null    float64
#  7   pokemon_female      863 non-null    object
#  8   pokemon_weight_grs  910 non-null    float64
# ...

# %%
df_attri.head(-500)
# Out:
#      Unnamed: 0         name   ndex      pokemon_species  pokemon_weight_kg  \
# 0             0  Fezandipiti    NaN              unknown                NaN
# 1             1       Staryu  120.0   Star Shape Pokémon               34.5
# 2             2     Squirtle    7.0  Tiny Turtle Pokémon                9.0
# 3             3      Snorlax  143.0     Sleeping Pokémon              460.0
# 4             4       Seadra  117.0       Dragon Pokémon               25.0
# ..          ...          ...    ...                  ...                ...
# 510         510    Crawdaunt  342.0        Rogue Pokémon               32.8
# 511         511      Anorith  347.0   Old Shrimp Pokémon               12.5
# 512         512      Altaria  334.0      Humming Pokémon               20.6
# 513         513       Aggron  306.0   Iron Armor Pokémon              360.0
# 514         514    Abomasnow  460.0   Frost Tree Pokémon              135.5
#
# ...

# %%
df_attri.tail()
# Out:
#       Unnamed: 0        name    ndex     pokemon_species  pokemon_weight_kg  \
# 1010        1010  Toedscruel   949.0     Woodear Pokémon               58.0
# 1011        1011    Wo-Chien  1001.0     Ruinous Pokémon               74.2
# 1012        1012   Toedscool   948.0     Woodear Pokémon               33.0
# 1013        1013     Wugtrio   961.0  Garden Eel Pokémon                5.4
# 1014        1014   Terapagos     NaN             unknown                NaN
#
#       pokemon_height_m  pokemon_male pokemon_female  pokemon_weight_grs
# 1010               1.9          50.0             50             58000.0
# 1011               1.5           NaN            NaN             74200.0
# 1012               0.9          50.0             50             33000.0
# 1013               1.2          50.0             50              5400.0
# 1014               NaN           NaN            NaN                 NaN

# %%
print(df_stats.shape, "\n")
print(df_stats.dtypes, "\n")
print(df_stats.info(), "\n")
df_stats.head()
# Out:
# (1194, 10)
#
# podedex_index     int64
# name             object
# form             object
# total             int64
# hp                int64
# attack            int64
# defense           int64
# sp_atk            int64
# sp_def            int64
# speed             int64
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   podedex_index  1194 non-null   int64
#  1   name           1194 non-null   object
#  2   form           1194 non-null   object
#  3   total          1194 non-null   int64
#  4   hp             1194 non-null   int64
#  5   attack         1194 non-null   int64
#  6   defense        1194 non-null   int64
#  7   sp_atk         1194 non-null   int64
#  8   sp_def         1194 non-null   int64
#  9   speed          1194 non-null   int64
# dtypes: int64(8), object(2)
# memory usage: 93.4+ KB
# None
# ...

# %%
df_stats.tail()
# Out:
#       podedex_index          name     form  total   hp  attack  defense  \
# 1189           1006  Iron Valiant  default    590   74     130       90
# 1190           1007      Koraidon  default    670  100     135      115
# 1191           1008      Miraidon  default    670  100      85      100
# 1192           1009  Walking Wake  default    590   99      83       91
# 1193           1010   Iron Leaves  default    590   90     130       88
#
#       sp_atk  sp_def  speed
# 1189     120      60    116
# 1190      85     100    135
# 1191     135     115    135
# 1192     125      83    109
# 1193      70     108    104

# %%
df_stats.drop_duplicates()
# Out:
#       podedex_index          name              form  total   hp  attack  \
# 0                 3      Venusaur     Mega Venusaur    625   80     100
# 1                 6     Charizard  Mega Charizard X    634   78     130
# 2                 6     Charizard  Mega Charizard Y    634   78     104
# 3                 9     Blastoise    Mega Blastoise    630   79     103
# 4                15      Beedrill     Mega Beedrill    495   65     150
# ...             ...           ...               ...    ...  ...     ...
# 1189           1006  Iron Valiant           default    590   74     130
# 1190           1007      Koraidon           default    670  100     135
# 1191           1008      Miraidon           default    670  100      85
# 1192           1009  Walking Wake           default    590   99      83
# 1193           1010   Iron Leaves           default    590   90     130
#
#       defense  sp_atk  sp_def  speed
# 0         123     122     120     80
# ...

# %%
print(df_type.shape, "\n")
print(df_type.dtypes, "\n")
print(df_type.info(), "\n")
df_type.head()
# Out:
# (1015, 4)
#
# name       object
# ndex      float64
# tipo_1     object
# tipo_2     object
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    1015 non-null   object
#  1   ndex    1010 non-null   float64
#  2   tipo_1  1015 non-null   object
#  3   tipo_2  765 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 31.8+ KB
# None
#       name   ndex  tipo_1 tipo_2
# 0  Seaking  119.0   water    bug
# 1  Grovyle  253.0   grass    bug
# 2  Armaldo  348.0    rock    bug
# 3  Anorith  347.0    rock    bug
# 4  Skorupi  451.0  poison    bug

# %%
df_type.tail()
# Out:
#            name   ndex   tipo_1 tipo_2
# 1010   Cetoddle  974.0      ice    NaN
# 1011   Capsakid  951.0    grass    NaN
# 1012    Cetitan  975.0      ice    NaN
# 1013    Wugtrio  961.0    water    NaN
# 1014  Terapagos    NaN  unknown    NaN

# %%
df_stats['name'].value_counts().head(20)
# Out:
# name
# Rotom           6
# Tauros          4
# Deoxys          4
# Darmanitan      4
# Pumpkaboo       4
# Gourgeist       4
# Oricorio        4
# Necrozma        4
# Squawkabilly    4
# Castform        4
# Slowbro         3
# Lycanroc        3
# Burmy           3
# Calyrex         3
# Wormadam        3
# Kyurem          3
# Meowth          3
# Tatsugiri       3
# Zygarde         3
# Basculin        3
# Name: count, dtype: int64

# %% [markdown]
# Desafío 2: 🧹  Limpieza de Datos
#
# * Une los tres DataFrames en un solo DataFrame, utilizando el código de Pokémon como clave.
# * Comprueba si existen registros duplicados y, si los hay, eliminalos.
# * Unifica las columnas de peso (Kg y Gr) en una sola de Kg.
# * Comprueba si existen valores faltantes y decide cómo manejarlos. Ten en cuenta que podrías necesitar diferentes estrategias para diferentes columnas.

# %%
df_attri=df_attri.drop_duplicates()
df_attri
# Out:
#       Unnamed: 0         name    ndex      pokemon_species  pokemon_weight_kg  \
# 0              0  Fezandipiti     NaN              unknown                NaN
# 1              1       Staryu   120.0   Star Shape Pokémon               34.5
# 2              2     Squirtle     7.0  Tiny Turtle Pokémon                9.0
# 3              3      Snorlax   143.0     Sleeping Pokémon              460.0
# 4              4       Seadra   117.0       Dragon Pokémon               25.0
# ...          ...          ...     ...                  ...                ...
# 1010        1010   Toedscruel   949.0      Woodear Pokémon               58.0
# 1011        1011     Wo-Chien  1001.0      Ruinous Pokémon               74.2
# 1012        1012    Toedscool   948.0      Woodear Pokémon               33.0
# 1013        1013      Wugtrio   961.0   Garden Eel Pokémon                5.4
# 1014        1014    Terapagos     NaN              unknown                NaN
#
# ...

# %%
df_stats=df_stats.drop_duplicates()
df_stats
# Out:
#       podedex_index          name              form  total   hp  attack  \
# 0                 3      Venusaur     Mega Venusaur    625   80     100
# 1                 6     Charizard  Mega Charizard X    634   78     130
# 2                 6     Charizard  Mega Charizard Y    634   78     104
# 3                 9     Blastoise    Mega Blastoise    630   79     103
# 4                15      Beedrill     Mega Beedrill    495   65     150
# ...             ...           ...               ...    ...  ...     ...
# 1189           1006  Iron Valiant           default    590   74     130
# 1190           1007      Koraidon           default    670  100     135
# 1191           1008      Miraidon           default    670  100      85
# 1192           1009  Walking Wake           default    590   99      83
# 1193           1010   Iron Leaves           default    590   90     130
#
#       defense  sp_atk  sp_def  speed
# 0         123     122     120     80
# ...

# %%
df = pd.merge(df_attri, df_type[['name','tipo_1','tipo_2']], on='name')
#df = pd.merge(df_attri, df_type, on='name')
df
# Out:
#       Unnamed: 0         name    ndex      pokemon_species  pokemon_weight_kg  \
# 0              0  Fezandipiti     NaN              unknown                NaN
# 1              1       Staryu   120.0   Star Shape Pokémon               34.5
# 2              2     Squirtle     7.0  Tiny Turtle Pokémon                9.0
# 3              3      Snorlax   143.0     Sleeping Pokémon              460.0
# 4              4       Seadra   117.0       Dragon Pokémon               25.0
# ...          ...          ...     ...                  ...                ...
# 1010        1010   Toedscruel   949.0      Woodear Pokémon               58.0
# 1011        1011     Wo-Chien  1001.0      Ruinous Pokémon               74.2
# 1012        1012    Toedscool   948.0      Woodear Pokémon               33.0
# 1013        1013      Wugtrio   961.0   Garden Eel Pokémon                5.4
# 1014        1014    Terapagos     NaN              unknown                NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1015 non-null   int64
#  1   name                1015 non-null   object
#  2   ndex                1010 non-null   float64
#  3   pokemon_species     1015 non-null   object
#  4   pokemon_weight_kg   909 non-null    float64
#  5   pokemon_height_m    1003 non-null   float64
#  6   pokemon_male        862 non-null    float64
#  7   pokemon_female      863 non-null    object
#  8   pokemon_weight_grs  910 non-null    float64
#  9   tipo_1              1015 non-null   object
#  10  tipo_2              765 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 87.4+ KB

# %%
df_stats.columns
# Out:
# Index(['podedex_index', 'name', 'form', 'total', 'hp', 'attack', 'defense',
#        'sp_atk', 'sp_def', 'speed'],
#       dtype='object')

# %%
df = pd.merge(df, df_stats[['podedex_index', 'form', 'total', 'hp', 'attack', 'defense',
       'sp_atk', 'sp_def', 'speed']], left_on='Unnamed: 0', right_on='podedex_index')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1194 non-null   int64
#  1   name                1194 non-null   object
#  2   ndex                1188 non-null   float64
#  3   pokemon_species     1194 non-null   object
#  4   pokemon_weight_kg   1077 non-null   float64
#  5   pokemon_height_m    1181 non-null   float64
#  6   pokemon_male        1012 non-null   float64
#  7   pokemon_female      1013 non-null   object
#  8   pokemon_weight_grs  1070 non-null   float64
#  9   tipo_1              1194 non-null   object
#  10  tipo_2              882 non-null    object
#  11  podedex_index       1194 non-null   int64
#  12  form                1194 non-null   object
#  13  total               1194 non-null   int64
#  14  hp                  1194 non-null   int64
# ...

# %%
df_stats.columns
# Out:
# Index(['podedex_index', 'name', 'form', 'total', 'hp', 'attack', 'defense',
#        'sp_atk', 'sp_def', 'speed'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1194 non-null   int64
#  1   name                1194 non-null   object
#  2   ndex                1188 non-null   float64
#  3   pokemon_species     1194 non-null   object
#  4   pokemon_weight_kg   1077 non-null   float64
#  5   pokemon_height_m    1181 non-null   float64
#  6   pokemon_male        1012 non-null   float64
#  7   pokemon_female      1013 non-null   object
#  8   pokemon_weight_grs  1070 non-null   float64
#  9   tipo_1              1194 non-null   object
#  10  tipo_2              882 non-null    object
#  11  podedex_index       1194 non-null   int64
#  12  form                1194 non-null   object
#  13  total               1194 non-null   int64
#  14  hp                  1194 non-null   int64
# ...

# %%
df['name'].value_counts()
# Out:
# name
# Lunatone      6
# Marill        4
# Uxie          4
# Ducklett      4
# Durant        4
#              ..
# Natu          1
# Ledyba        1
# Ledian        1
# Larvitar      1
# Toedscruel    1
# Name: count, Length: 1010, dtype: int64

# %%
df[df['name']=='Lunatone']
# Out:
#      Unnamed: 0      name   ndex    pokemon_species  pokemon_weight_kg  \
# 582         479  Lunatone  337.0  Meteorite Pokémon              168.0
# 583         479  Lunatone  337.0  Meteorite Pokémon              168.0
# 584         479  Lunatone  337.0  Meteorite Pokémon              168.0
# 585         479  Lunatone  337.0  Meteorite Pokémon              168.0
# 586         479  Lunatone  337.0  Meteorite Pokémon              168.0
# 587         479  Lunatone  337.0  Meteorite Pokémon              168.0
#
#      pokemon_height_m  pokemon_male pokemon_female  pokemon_weight_grs tipo_1  \
# 582               1.0           NaN            NaN            168000.0   rock
# 583               1.0           NaN            NaN            168000.0   rock
# 584               1.0           NaN            NaN            168000.0   rock
# 585               1.0           NaN            NaN            168000.0   rock
# 586               1.0           NaN            NaN            168000.0   rock
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'ndex', 'pokemon_species', 'pokemon_weight_kg',
#        'pokemon_height_m', 'pokemon_male', 'pokemon_female',
#        'pokemon_weight_grs', 'tipo_1', 'tipo_2', 'podedex_index', 'form',
#        'total', 'hp', 'attack', 'defense', 'sp_atk', 'sp_def', 'speed'],
#       dtype='object')

# %%
df['podedex_index'].nunique()
# Out:
# 1010

# %%
df.drop_duplicates()
# Out:
#       Unnamed: 0        name   ndex       pokemon_species  pokemon_weight_kg  \
# 0              1      Staryu  120.0    Star Shape Pokémon               34.5
# 1              2    Squirtle    7.0   Tiny Turtle Pokémon                9.0
# 2              3     Snorlax  143.0      Sleeping Pokémon              460.0
# 3              3     Snorlax  143.0      Sleeping Pokémon              460.0
# 4              4      Seadra  117.0        Dragon Pokémon               25.0
# ...          ...         ...    ...                   ...                ...
# 1189        1006    Arctibax  997.0       Ice Fin Pokémon               30.0
# 1190        1007  Annihilape  979.0   Rage Monkey Pokémon               56.0
# 1191        1008     Wattrel  940.0  Storm Petrel Pokémon                3.6
# 1192        1009      Varoom  965.0    Single-Cyl Pokémon               35.0
# 1193        1010  Toedscruel  949.0       Woodear Pokémon               58.0
#
# ...

# %%
df['pokemon_weight_kg']*1000==df['pokemon_weight_grs']
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1189    False
# 1190    False
# 1191     True
# 1192     True
# 1193     True
# Length: 1194, dtype: bool

# %%
df[df['pokemon_weight_kg']*1000!=df['pokemon_weight_grs']][['pokemon_weight_kg','pokemon_weight_grs']]
# Out:
#       pokemon_weight_kg  pokemon_weight_grs
# 16                  NaN             19500.0
# 17                 70.3                 NaN
# 20                  NaN              6500.0
# 36                  NaN             33300.0
# 37                  NaN             33300.0
# ...                 ...                 ...
# 1175                NaN            240000.0
# 1180               30.7                 NaN
# 1185              700.0                 NaN
# 1189               30.0                 NaN
# 1190               56.0                 NaN
#
# [215 rows x 2 columns]

# %%
df['pokemon_weight_kg'].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1189    False
# 1190    False
# 1191    False
# 1192    False
# 1193    False
# Name: pokemon_weight_kg, Length: 1194, dtype: bool

# %%
df[df['pokemon_weight_kg'].isna() & df['pokemon_weight_grs'].isna()].head()
# Out:
#      Unnamed: 0     name   ndex   pokemon_species  pokemon_weight_kg  \
# 101          77   Plusle  311.0  Cheering Pokémon                NaN
# 102          77   Plusle  311.0  Cheering Pokémon                NaN
# 163         123     Sawk  539.0    Karate Pokémon                NaN
# 253         198  Chansey  113.0       Egg Pokémon                NaN
# 268         211  Okidogi    NaN           unknown                NaN
#
#      pokemon_height_m  pokemon_male pokemon_female  pokemon_weight_grs  \
# 101               0.4          50.0             50                 NaN
# 102               0.4          50.0             50                 NaN
# 163               1.4         100.0              0                 NaN
# 253               1.1           0.0            100                 NaN
# 268               NaN           NaN            NaN                 NaN
#
#        tipo_1 tipo_2  podedex_index              form  total  hp  attack  \
# ...

# %%
df[(df['pokemon_weight_kg'].notna()) & (df['pokemon_weight_grs'].notna()) & (df['pokemon_weight_kg']*1000!=df['pokemon_weight_grs'])]
# Out:
#      Unnamed: 0         name   ndex    pokemon_species  pokemon_weight_kg  \
# 954         796  Blacephalon  806.0  Fireworks Pokémon              130.2
#
#      pokemon_height_m  pokemon_male pokemon_female  pokemon_weight_grs tipo_1  \
# 954               1.8           NaN            NaN            130200.0   fire
#
#     tipo_2  podedex_index     form  total  hp  attack  defense  sp_atk  \
# 954  ghost            796  default    570  83      89       71     173
#
#      sp_def  speed
# 954      71     83

# %%
k=df.loc[954]['pokemon_weight_kg']

# %%
g=df.loc[954]['pokemon_weight_grs']

# %%
k*1000==g
# Out:
# False

# %%
print(1000*k,g)
# Out:
# 130199.99999999999 130200.0

# %%
df[df['pokemon_weight_kg'].isna() & df['pokemon_weight_grs'].notna()]
# Out:
#       Unnamed: 0          name   ndex       pokemon_species  \
# 16            13        Machop   66.0    Superpower Pokémon
# 20            16        Krabby   98.0    River Crab Pokémon
# 36            27       Dugtrio   51.0          Mole Pokémon
# 37            27       Dugtrio   51.0          Mole Pokémon
# 46            35       Blissey  242.0     Happiness Pokémon
# ...          ...           ...    ...                   ...
# 1121         943  Slither Wing  988.0       Paradox Pokémon
# 1124         946    Skeledirge  911.0        Singer Pokémon
# 1126         948    Scovillain  952.0  Spicy Pepper Pokémon
# 1133         955         Pawmo  922.0         Mouse Pokémon
# 1175         993     Garganacl  934.0     Rock Salt Pokémon
#
#       pokemon_weight_kg  pokemon_height_m  pokemon_male pokemon_female  \
# 16                  NaN               0.8          75.0             25
# 20                  NaN               0.4          50.0             50
# ...

# %%
df['pokemon_weight_kg']=df[df['pokemon_weight_kg'].isna() & df['pokemon_weight_grs'].notna()]['pokemon_weight_grs']/1000

# %%
df
# Out:
#       Unnamed: 0        name   ndex       pokemon_species  pokemon_weight_kg  \
# 0              1      Staryu  120.0    Star Shape Pokémon                NaN
# 1              2    Squirtle    7.0   Tiny Turtle Pokémon                NaN
# 2              3     Snorlax  143.0      Sleeping Pokémon                NaN
# 3              3     Snorlax  143.0      Sleeping Pokémon                NaN
# 4              4      Seadra  117.0        Dragon Pokémon                NaN
# ...          ...         ...    ...                   ...                ...
# 1189        1006    Arctibax  997.0       Ice Fin Pokémon                NaN
# 1190        1007  Annihilape  979.0   Rage Monkey Pokémon                NaN
# 1191        1008     Wattrel  940.0  Storm Petrel Pokémon                NaN
# 1192        1009      Varoom  965.0    Single-Cyl Pokémon                NaN
# 1193        1010  Toedscruel  949.0       Woodear Pokémon                NaN
#
# ...

# %%
#por lo visto no se puede poner el campo a calcular dentro del filtro
#df['pokemon_weight_kg']=df[df['pokemon_weight_kg'].isna() & df['pokemon_weight_grs'].notna()]['pokemon_weight_grs']/1000
#df['pokemon_weight_kg']=df[df['pokemon_weight_kg'].isna()]['pokemon_weight_grs']/1000
df
# Out:
#       Unnamed: 0        name   ndex       pokemon_species  pokemon_weight_kg  \
# 0              1      Staryu  120.0    Star Shape Pokémon                NaN
# 1              2    Squirtle    7.0   Tiny Turtle Pokémon                NaN
# 2              3     Snorlax  143.0      Sleeping Pokémon                NaN
# 3              3     Snorlax  143.0      Sleeping Pokémon                NaN
# 4              4      Seadra  117.0        Dragon Pokémon                NaN
# ...          ...         ...    ...                   ...                ...
# 1189        1006    Arctibax  997.0       Ice Fin Pokémon                NaN
# 1190        1007  Annihilape  979.0   Rage Monkey Pokémon                NaN
# 1191        1008     Wattrel  940.0  Storm Petrel Pokémon                NaN
# 1192        1009      Varoom  965.0    Single-Cyl Pokémon                NaN
# 1193        1010  Toedscruel  949.0       Woodear Pokémon                NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1194 non-null   int64
#  1   name                1194 non-null   object
#  2   ndex                1188 non-null   float64
#  3   pokemon_species     1194 non-null   object
#  4   pokemon_weight_kg   90 non-null     float64
#  5   pokemon_height_m    1181 non-null   float64
#  6   pokemon_male        1012 non-null   float64
#  7   pokemon_female      1013 non-null   object
#  8   pokemon_weight_grs  1070 non-null   float64
#  9   tipo_1              1194 non-null   object
#  10  tipo_2              882 non-null    object
#  11  podedex_index       1194 non-null   int64
#  12  form                1194 non-null   object
#  13  total               1194 non-null   int64
#  14  hp                  1194 non-null   int64
# ...

# %%
df[df['pokemon_weight_kg'].isna() & df['pokemon_weight_grs'].notna()]
# Out:
#       Unnamed: 0          name   ndex       pokemon_species  \
# 16            13        Machop   66.0    Superpower Pokémon
# 20            16        Krabby   98.0    River Crab Pokémon
# 36            27       Dugtrio   51.0          Mole Pokémon
# 37            27       Dugtrio   51.0          Mole Pokémon
# 46            35       Blissey  242.0     Happiness Pokémon
# ...          ...           ...    ...                   ...
# 1121         943  Slither Wing  988.0       Paradox Pokémon
# 1124         946    Skeledirge  911.0        Singer Pokémon
# 1126         948    Scovillain  952.0  Spicy Pepper Pokémon
# 1133         955         Pawmo  922.0         Mouse Pokémon
# 1175         993     Garganacl  934.0     Rock Salt Pokémon
#
#       pokemon_weight_kg  pokemon_height_m  pokemon_male pokemon_female  \
# 16                  NaN               0.8          75.0             25
# 20                  NaN               0.4          50.0             50
# ...

# %%
df['pokemon_weight_kg']=df['pokemon_weight_kg'].fillna(df['pokemon_weight_grs']/1000)

# %%
df
# Out:
#       Unnamed: 0        name   ndex       pokemon_species  pokemon_weight_kg  \
# 0              1      Staryu  120.0    Star Shape Pokémon               34.5
# 1              2    Squirtle    7.0   Tiny Turtle Pokémon                9.0
# 2              3     Snorlax  143.0      Sleeping Pokémon              460.0
# 3              3     Snorlax  143.0      Sleeping Pokémon              460.0
# 4              4      Seadra  117.0        Dragon Pokémon               25.0
# ...          ...         ...    ...                   ...                ...
# 1189        1006    Arctibax  997.0       Ice Fin Pokémon                NaN
# 1190        1007  Annihilape  979.0   Rage Monkey Pokémon                NaN
# 1191        1008     Wattrel  940.0  Storm Petrel Pokémon                3.6
# 1192        1009      Varoom  965.0    Single-Cyl Pokémon               35.0
# 1193        1010  Toedscruel  949.0       Woodear Pokémon               58.0
#
# ...

# %%
df[df['pokemon_weight_kg'].isna()]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 124 entries, 17 to 1190
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          124 non-null    int64
#  1   name                124 non-null    object
#  2   ndex                118 non-null    float64
#  3   pokemon_species     124 non-null    object
#  4   pokemon_weight_kg   0 non-null      float64
#  5   pokemon_height_m    115 non-null    float64
#  6   pokemon_male        108 non-null    float64
#  7   pokemon_female      108 non-null    object
#  8   pokemon_weight_grs  0 non-null      float64
#  9   tipo_1              124 non-null    object
#  10  tipo_2              90 non-null     object
#  11  podedex_index       124 non-null    int64
#  12  form                124 non-null    object
#  13  total               124 non-null    int64
#  14  hp                  124 non-null    int64
# ...

# %%
df[df['pokemon_weight_grs'].isna()]
# Out:
#       Unnamed: 0        name   ndex      pokemon_species  pokemon_weight_kg  \
# 17            14     Machoke   67.0   Superpower Pokémon                NaN
# 76            58    Chimecho  358.0   Wind Chime Pokémon                NaN
# 77            58    Chimecho  358.0   Wind Chime Pokémon                NaN
# 87            66     Treecko  252.0   Wood Gecko Pokémon                NaN
# 97            75      Skitty  300.0       Kitten Pokémon                NaN
# ...          ...         ...    ...                  ...                ...
# 1172         990   Ceruledge  937.0  Fire Blades Pokémon                NaN
# 1180         998    Crocalor  910.0    Fire Croc Pokémon                NaN
# 1185        1002     Cetitan  975.0  Terra Whale Pokémon                NaN
# 1189        1006    Arctibax  997.0      Ice Fin Pokémon                NaN
# 1190        1007  Annihilape  979.0  Rage Monkey Pokémon                NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1194 non-null   int64
#  1   name                1194 non-null   object
#  2   ndex                1188 non-null   float64
#  3   pokemon_species     1194 non-null   object
#  4   pokemon_weight_kg   1070 non-null   float64
#  5   pokemon_height_m    1181 non-null   float64
#  6   pokemon_male        1012 non-null   float64
#  7   pokemon_female      1013 non-null   object
#  8   pokemon_weight_grs  1070 non-null   float64
#  9   tipo_1              1194 non-null   object
#  10  tipo_2              882 non-null    object
#  11  podedex_index       1194 non-null   int64
#  12  form                1194 non-null   object
#  13  total               1194 non-null   int64
#  14  hp                  1194 non-null   int64
# ...

# %%
df.iloc[100:200]
# Out:
#      Unnamed: 0       name   ndex       pokemon_species  pokemon_weight_kg  \
# 100          76   Sceptile  254.0        Forest Pokémon                NaN
# 101          77     Plusle  311.0      Cheering Pokémon                NaN
# 102          77     Plusle  311.0      Cheering Pokémon                NaN
# 103          78   Nosepass  299.0       Compass Pokémon               97.0
# 104          78   Nosepass  299.0       Compass Pokémon               97.0
# ..          ...        ...    ...                   ...                ...
# 195         146    Sylveon  700.0  Intertwining Pokémon               23.5
# 196         146    Sylveon  700.0  Intertwining Pokémon               23.5
# 197         147  Quilladin  651.0   Spiny Armor Pokémon               29.0
# 198         148    Furfrou  676.0        Poodle Pokemon               28.0
# 199         149    Florges  671.0        Garden Pokémon               10.0
#
# ...

# %% [markdown]
# Desafío 3: 🔍  Análisis Exploratorio de Datos
#
# Calcula estadísticas descriptivas para las columnas numéricas (media, mediana, desviación estándar, valor mínimo, valor máximo).
# Descubre cuántos valores únicos hay en las columnas categóricas.
# Determina cuántos valores faltantes existen en cada columna.
